# %% [markdown]
# <a href="https://colab.research.google.com/github/Ahmed-Gomaa1/Api-For-Deep-learning-Model-Classifying-White-spots/blob/master/Final_Try.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Libraries

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from keras.layers import Conv2D,MaxPool2D,AveragePooling2D,Dense,Flatten,ZeroPadding2D,BatchNormalization,Activation,Add,Input,Dropout,GlobalAveragePooling2D
from keras.layers.reshaping.flatten import Flatten
from keras.applications import VGG16
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.models import Model
from tensorflow import keras
from keras import metrics
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import accuracy_score, classification_report
from matplotlib import pyplot as plt
import tensorflow
import tensorflow as tf
import seaborn as sns
import numpy as np
import plotly
import os
import glob
import warnings
warnings.filterwarnings(action='ignore')

# %% [markdown]
# #More Data Augmentation

# %% [markdown]
# I Loob in every directory for generate 5 images from every image in every class , and save all images related to one of classes in new directory

# %%
'''
path = "/content/drive/MyDrive/Colab Notebooks/Graduation Project/training/Viti"

filenames=os.listdir(path)
datagen = ImageDataGenerator(
      rotation_range=60,
      shear_range=0.15,
      zoom_range=0.3,
      horizontal_flip=True,
      fill_mode='nearest')

for f in filenames:
    img = keras.preprocessing.image.load_img(f"/content/drive/MyDrive/Colab Notebooks/Graduation Project/training/Vitiligo/{f}")
    x = keras.preprocessing.image.img_to_array(img)
    # Reshape the input image
    x = x.reshape((1, ) + x.shape)
    i = 0

    # generate 5 new augmented images
    for batch in datagen.flow(x, batch_size = 1,
                      save_to_dir ='/content/drive/MyDrive/Colab Notebooks/Graduation Project/training/Viti',
                      save_prefix ='Viti', save_format ='jpeg'):
        i += 1
        if i > 5:
          break
'''

# %% [markdown]
# # Loading Image Files

# %%
Images=ImageDataGenerator(
      validation_split=0.20,
      brightness_range=(0.5,1.4)
      )
TrainG = Images.flow_from_directory('/content/drive/MyDrive/Colab Notebooks/Graduation Project/training',subset="training",target_size=(100,100),shuffle=True,seed=42)
ValidG = Images.flow_from_directory('/content/drive/MyDrive/Colab Notebooks/Graduation Project/training',subset="validation",target_size=(100,100),shuffle=True,seed=42)
testD = ImageDataGenerator().flow_from_directory('/content/drive/MyDrive/Colab Notebooks/Graduation Project/testing',target_size=(100,100),shuffle=False,seed=42)
# Out:
# Found 2572 images belonging to 4 classes.
# Found 640 images belonging to 4 classes.
# Found 60 images belonging to 4 classes.

# %%
classes=list(TrainG.class_indices.keys())
plt.figure(figsize=(20,20))
for X_batch, y_batch in TrainG:
    for i in range(0,15):
        plt.subplot(5,5,i+1)
        plt.imshow(X_batch[i].astype(np.uint8))
        plt.title(classes[np.where(y_batch[i]==1)[0][0]])
    plt.show()
    break

# %% [markdown]
# #ResNet50

# %%
ResnetModel=keras.applications.ResNet50(include_top=False,weights='imagenet',input_shape=(100,100,3),classes=4)
ResnetModel.trainable=False
pt=Input(shape=(100,100,3))
func=tensorflow.cast(pt,tensorflow.float32)
x=preprocess_input(func)
model_resnet=ResnetModel(x,training=False)
model_resnet=GlobalAveragePooling2D()(model_resnet)
model_resnet=Dropout(0.35)(model_resnet)
model_resnet=Dense(256,activation='relu',kernel_regularizer =tf.keras.regularizers.l2( l=0.01))(model_resnet)
model_resnet=Dense(512,activation='relu',kernel_regularizer =tf.keras.regularizers.l2( l=0.01))(model_resnet)
model_resnet=Dense(512,activation='relu',kernel_regularizer =tf.keras.regularizers.l2( l=0.01))(model_resnet)
model_resnet=Dense(128,activation='relu',kernel_regularizer =tf.keras.regularizers.l2( l=0.01))(model_resnet)
model_resnet=Dropout(0.15)(model_resnet)
model_resnet=Dense(4,activation='softmax')(model_resnet)
Model_1=Model(inputs=pt,outputs=model_resnet)
Model_1.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 3s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 100, 100, 3)]     0
#
#  tf.cast (TFOpLambda)        (None, 100, 100, 3)       0
#
#  tf.__operators__.getitem (S  (None, 100, 100, 3)      0
#  licingOpLambda)
#
#  tf.nn.bias_add (TFOpLambda)  (None, 100, 100, 3)      0
#
#  resnet50 (Functional)       (None, 4, 4, 2048)        23587712
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense (Dense)               (None, 256)               524544
#
#  dense_1 (Dense)             (None, 512)               131584
#
#  dense_2 (Dense)             (None, 512)               262656
#
#  dense_3 (Dense)             (None, 128)               65664
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 24,572,676
# Trainable params: 984,964
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %%
Model_1.compile(optimizer=keras.optimizers.Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])
train_model = Model_1.fit(TrainG,validation_data=ValidG,epochs=40,batch_size=64)
# Out:
# Epoch 1/40
# 81/81 [==============================] - 1096s 14s/step - loss: 15.3582 - accuracy: 0.5474 - val_loss: 14.1853 - val_accuracy: 0.7578
# Epoch 2/40
# 81/81 [==============================] - 177s 2s/step - loss: 13.5010 - accuracy: 0.7240 - val_loss: 12.6168 - val_accuracy: 0.7984
# Epoch 3/40
# 81/81 [==============================] - 175s 2s/step - loss: 12.0507 - accuracy: 0.7609 - val_loss: 11.3326 - val_accuracy: 0.8062
# Epoch 4/40
# 81/81 [==============================] - 174s 2s/step - loss: 10.8012 - accuracy: 0.7904 - val_loss: 10.1679 - val_accuracy: 0.8219
# Epoch 5/40
# 81/81 [==============================] - 175s 2s/step - loss: 9.7101 - accuracy: 0.8235 - val_loss: 9.1874 - val_accuracy: 0.8531
# Epoch 6/40
# 81/81 [==============================] - 177s 2s/step - loss: 8.7840 - accuracy: 0.8402 - val_loss: 8.4312 - val_accuracy: 0.8016
# Epoch 7/40
# 81/81 [==============================] - 175s 2s/step - loss: 7.9745 - accuracy: 0.8456 - val_loss: 7.5927 - val_accuracy: 0.8609
# Epoch 8/40
# 81/81 [==============================] - 175s 2s/step - loss: 7.2583 - accuracy: 0.8686 - val_loss: 6.9708 - val_accuracy: 0.8609
# Epoch 9/40
# 81/81 [==============================] - 174s 2s/step - loss: 6.6284 - accuracy: 0.8822 - val_loss: 6.3878 - val_accuracy: 0.8547
# Epoch 10/40
# 81/81 [==============================] - 172s 2s/step - loss: 6.1115 - accuracy: 0.8682 - val_loss: 5.8507 - val_accuracy: 0.8797
# Epoch 11/40
# 81/81 [==============================] - 173s 2s/step - loss: 5.6291 - accuracy: 0.8822 - val_loss: 5.4405 - val_accuracy: 0.8734
# Epoch 12/40
# 81/81 [==============================] - 172s 2s/step - loss: 5.1825 - accuracy: 0.8954 - val_loss: 5.0027 - val_accuracy: 0.8953
# Epoch 13/40
# 81/81 [==============================] - 175s 2s/step - loss: 4.8030 - accuracy: 0.9020 - val_loss: 4.6984 - val_accuracy: 0.8734
# Epoch 14/40
# 81/81 [==============================] - 165s 2s/step - loss: 4.4820 - accuracy: 0.9005 - val_loss: 4.3334 - val_accuracy: 0.8953
# Epoch 15/40
# 81/81 [==============================] - 178s 2s/step - loss: 4.1672 - accuracy: 0.9149 - val_loss: 4.1096 - val_accuracy: 0.8750
# Epoch 16/40
# 81/81 [==============================] - 181s 2s/step - loss: 3.8895 - accuracy: 0.9141 - val_loss: 3.7819 - val_accuracy: 0.8984
# Epoch 17/40
# 81/81 [==============================] - 167s 2s/step - loss: 3.6358 - accuracy: 0.9176 - val_loss: 3.5545 - val_accuracy: 0.8859
# Epoch 18/40
# 81/81 [==============================] - 172s 2s/step - loss: 3.4290 - accuracy: 0.9145 - val_loss: 3.3595 - val_accuracy: 0.9000
# Epoch 19/40
# 81/81 [==============================] - 172s 2s/step - loss: 3.1989 - accuracy: 0.9250 - val_loss: 3.1431 - val_accuracy: 0.9078
# Epoch 20/40
# 81/81 [==============================] - 174s 2s/step - loss: 3.0185 - accuracy: 0.9191 - val_loss: 2.9544 - val_accuracy: 0.9109
# Epoch 21/40
# 81/81 [==============================] - 179s 2s/step - loss: 2.8405 - accuracy: 0.9261 - val_loss: 2.8140 - val_accuracy: 0.9016
# Epoch 22/40
# 81/81 [==============================] - 180s 2s/step - loss: 2.6764 - accuracy: 0.9296 - val_loss: 2.6662 - val_accuracy: 0.8984
# Epoch 23/40
# 81/81 [==============================] - 180s 2s/step - loss: 2.5417 - accuracy: 0.9234 - val_loss: 2.5354 - val_accuracy: 0.8938
# Epoch 24/40
# 81/81 [==============================] - 179s 2s/step - loss: 2.3952 - accuracy: 0.9277 - val_loss: 2.3785 - val_accuracy: 0.9125
# Epoch 25/40
# 81/81 [==============================] - 175s 2s/step - loss: 2.2672 - accuracy: 0.9265 - val_loss: 2.2838 - val_accuracy: 0.9047
# Epoch 26/40
# 81/81 [==============================] - 178s 2s/step - loss: 2.1470 - accuracy: 0.9382 - val_loss: 2.1795 - val_accuracy: 0.9016
# Epoch 27/40
# 81/81 [==============================] - 171s 2s/step - loss: 2.0302 - accuracy: 0.9393 - val_loss: 2.0419 - val_accuracy: 0.9016
# Epoch 28/40
# 81/81 [==============================] - 177s 2s/step - loss: 1.9368 - accuracy: 0.9393 - val_loss: 1.9198 - val_accuracy: 0.9266
# Epoch 29/40
# 81/81 [==============================] - 175s 2s/step - loss: 1.8293 - accuracy: 0.9397 - val_loss: 1.8371 - val_accuracy: 0.9328
# Epoch 30/40
# 81/81 [==============================] - 179s 2s/step - loss: 1.7562 - accuracy: 0.9425 - val_loss: 1.7857 - val_accuracy: 0.9141
# Epoch 31/40
# 81/81 [==============================] - 177s 2s/step - loss: 1.6623 - accuracy: 0.9460 - val_loss: 1.6672 - val_accuracy: 0.9219
# Epoch 32/40
# 81/81 [==============================] - 168s 2s/step - loss: 1.6097 - accuracy: 0.9339 - val_loss: 1.6268 - val_accuracy: 0.9094
# Epoch 33/40
# 81/81 [==============================] - 177s 2s/step - loss: 1.5304 - accuracy: 0.9417 - val_loss: 1.5657 - val_accuracy: 0.9156
# Epoch 34/40
# 81/81 [==============================] - 169s 2s/step - loss: 1.4496 - accuracy: 0.9456 - val_loss: 1.4838 - val_accuracy: 0.9250
# Epoch 35/40
# 81/81 [==============================] - 177s 2s/step - loss: 1.3873 - accuracy: 0.9479 - val_loss: 1.4281 - val_accuracy: 0.9187
# Epoch 36/40
# 81/81 [==============================] - 178s 2s/step - loss: 1.3490 - accuracy: 0.9370 - val_loss: 1.3882 - val_accuracy: 0.9234
# Epoch 37/40
# 81/81 [==============================] - 177s 2s/step - loss: 1.2865 - accuracy: 0.9401 - val_loss: 1.3287 - val_accuracy: 0.9094
# Epoch 38/40
# 81/81 [==============================] - 177s 2s/step - loss: 1.2283 - accuracy: 0.9514 - val_loss: 1.2809 - val_accuracy: 0.9156
# Epoch 39/40
# 81/81 [==============================] - 179s 2s/step - loss: 1.1588 - accuracy: 0.9561 - val_loss: 1.1964 - val_accuracy: 0.9344
# Epoch 40/40
# 81/81 [==============================] - 179s 2s/step - loss: 1.1278 - accuracy: 0.9541 - val_loss: 1.2052 - val_accuracy: 0.9141

# %%
plt.figure(figsize=(10,10))
plt.style.use("dark_background")
plt.plot(train_model.history['loss'],marker="o",linestyle="-",color="wheat",markersize=10,lw=4)
plt.plot(train_model.history['val_loss'],marker="o",linestyle="-",color="turquoise",markersize=10,lw=4)
plt.title('Model Loss\n',color="lavender",fontsize=20)
plt.ylabel('Loss',color="lavender",fontsize=15)
plt.xlabel('Epoch',color="lavender",fontsize=15)
plt.legend(['Train_Loss', 'Valid_Loss'], loc='upper left')
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.style.use("dark_background")
plt.plot(train_model.history['accuracy'],marker="o",linestyle="-",color="yellow",markersize=10,lw=4)
plt.plot(train_model.history['val_accuracy'],marker="o",linestyle="-",color="darkcyan",markersize=10,lw=4)
plt.title('Model Accuracy\n',color="lavender",fontsize=20)
plt.ylabel('Accuracy',color="lavender",fontsize=15)
plt.xlabel('Epoch',color="lavender",fontsize=15)
plt.legend(['Train_Accuracy', 'Valid_accuracy'], loc='upper left')
plt.show()

# %%
CLASS_NAMES = list(TrainG.class_indices.keys())
predictions = np.argmax(Model_1.predict(testD), axis=1)

acc = accuracy_score(testD.labels, predictions)
cm = tf.math.confusion_matrix(testD.labels, predictions)
clr = classification_report(testD.labels, predictions, target_names=CLASS_NAMES)

print("Test Accuracy: {:.3f} %".format(acc * 100))

plt.figure(figsize=(8, 8))
sns.heatmap(cm, annot=True, fmt='g', vmin=0, cmap='Greens', cbar=False)
plt.xticks(ticks=np.arange(4)+0.5 , labels=CLASS_NAMES)
plt.yticks(ticks=np.arange(4)+0.5 , labels=CLASS_NAMES)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

print("Classification Report:\n-----------------------------\n", clr)
# Out:
# 2/2 [==============================] - 8s 2s/step
# Test Accuracy: 91.667 %
# Classification Report:
# -----------------------------
#                    precision    recall  f1-score   support
#
#      Normal Case       0.94      1.00      0.97        15
#  Pityriasis Alpa       0.81      0.87      0.84        15
# Tinea Versicolor       1.00      0.87      0.93        15
#         Vitiligo       0.93      0.93      0.93        15
#
#         accuracy                           0.92        60
#        macro avg       0.92      0.92      0.92        60
#     weighted avg       0.92      0.92      0.92        60

# %% [markdown]
# #VGG19

# %%
VGG19_Model=keras.applications.VGG19(include_top=False,weights='imagenet',input_shape=(100,100,3),classes=4)
VGG19_Model.trainable=False
pt=Input(shape=(100,100,3))
func=tensorflow.cast(pt,tensorflow.float32)
x=preprocess_input(func)
VGG19Model=VGG19_Model(x,training=False)
VGG19Model=GlobalAveragePooling2D()(VGG19Model)
VGG19Model=Dense(800,activation='relu',kernel_regularizer =tf.keras.regularizers.l2( l=0.01))(VGG19Model)
VGG19Model=Dense(250,activation='relu',kernel_regularizer =tf.keras.regularizers.l2( l=0.01))(VGG19Model)
VGG19Model=Dense(200,activation='relu',kernel_regularizer =tf.keras.regularizers.l2( l=0.01))(VGG19Model)
VGG19Model=Dense(120,activation='relu',kernel_regularizer =tf.keras.regularizers.l2( l=0.01))(VGG19Model)
VGG19Model=Dense(4,activation='softmax')(VGG19Model)
Model_6=Model(inputs=pt,outputs=VGG19Model)
Model_6.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 3s 0us/step
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 100, 100, 3)]     0
#
#  tf.cast_2 (TFOpLambda)      (None, 100, 100, 3)       0
#
#  tf.__operators__.getitem_2   (None, 100, 100, 3)      0
#  (SlicingOpLambda)
#
#  tf.nn.bias_add_2 (TFOpLambd  (None, 100, 100, 3)      0
#  a)
#
#  vgg19 (Functional)          (None, 3, 3, 512)         20024384
#
#  global_average_pooling2d_1   (None, 512)              0
#  (GlobalAveragePooling2D)
#
#  dense_8 (Dense)             (None, 800)               410400
#
#  dense_9 (Dense)             (None, 250)               200250
#
#  dense_10 (Dense)            (None, 200)               50200
#
#  dense_11 (Dense)            (None, 120)               24120
#
#  dense_12 (Dense)            (None, 4)                 484
#
# =================================================================
# Total params: 20,709,838
# Trainable params: 685,454
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
Model_6.compile(optimizer=keras.optimizers.RMSprop(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])
train_model = Model_6.fit(TrainG,validation_data=ValidG,epochs=15)
# Out:
# Epoch 1/15
# 81/81 [==============================] - 542s 7s/step - loss: 10.8866 - accuracy: 0.6089 - val_loss: 6.8239 - val_accuracy: 0.6797
# Epoch 2/15
# 81/81 [==============================] - 545s 7s/step - loss: 4.6712 - accuracy: 0.7679 - val_loss: 3.1184 - val_accuracy: 0.7891
# Epoch 3/15
# 81/81 [==============================] - 543s 7s/step - loss: 2.3010 - accuracy: 0.8161 - val_loss: 1.7831 - val_accuracy: 0.8172
# Epoch 4/15
# 81/81 [==============================] - 551s 7s/step - loss: 1.4023 - accuracy: 0.8332 - val_loss: 1.1895 - val_accuracy: 0.8375
# Epoch 5/15
# 81/81 [==============================] - 544s 7s/step - loss: 1.0009 - accuracy: 0.8647 - val_loss: 0.9777 - val_accuracy: 0.8625
# Epoch 6/15
# 81/81 [==============================] - 543s 7s/step - loss: 0.7951 - accuracy: 0.8814 - val_loss: 0.8753 - val_accuracy: 0.8266
# Epoch 7/15
# 81/81 [==============================] - 540s 7s/step - loss: 0.6508 - accuracy: 0.9016 - val_loss: 0.7332 - val_accuracy: 0.8609
# Epoch 8/15
# 81/81 [==============================] - 540s 7s/step - loss: 0.5827 - accuracy: 0.9141 - val_loss: 0.7925 - val_accuracy: 0.8203
# Epoch 9/15
# 81/81 [==============================] - 538s 7s/step - loss: 0.5149 - accuracy: 0.9250 - val_loss: 0.6818 - val_accuracy: 0.8672
# Epoch 10/15
# 81/81 [==============================] - 539s 7s/step - loss: 0.4812 - accuracy: 0.9257 - val_loss: 0.7314 - val_accuracy: 0.8313
# Epoch 11/15
# 81/81 [==============================] - 548s 7s/step - loss: 0.4481 - accuracy: 0.9312 - val_loss: 0.5598 - val_accuracy: 0.8813
# Epoch 12/15
# 81/81 [==============================] - 553s 7s/step - loss: 0.4327 - accuracy: 0.9288 - val_loss: 0.5823 - val_accuracy: 0.8719
# Epoch 13/15
# 81/81 [==============================] - 548s 7s/step - loss: 0.3873 - accuracy: 0.9428 - val_loss: 0.5757 - val_accuracy: 0.8703
# Epoch 14/15
# 81/81 [==============================] - 551s 7s/step - loss: 0.3749 - accuracy: 0.9456 - val_loss: 0.5909 - val_accuracy: 0.8859
# Epoch 15/15
# 81/81 [==============================] - 548s 7s/step - loss: 0.3730 - accuracy: 0.9432 - val_loss: 0.5226 - val_accuracy: 0.8922

# %%
plt.figure(figsize=(10,10))
plt.style.use("dark_background")
plt.plot(train_model.history['loss'],marker="o",linestyle="-",color="wheat",markersize=10,lw=4)
plt.plot(train_model.history['val_loss'],marker="o",linestyle="-",color="turquoise",markersize=10,lw=4)
plt.title('Model Loss\n',color="snow",fontsize=20)
plt.ylabel('Loss',color="snow",fontsize=15)
plt.xlabel('Epoch',color="snow",fontsize=15)
plt.legend(['Train_Loss', 'Test_Loss'], loc='upper left')
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.style.use("dark_background")
plt.plot(train_model.history['accuracy'],marker="o",linestyle="-",color="yellow",markersize=10,lw=4)
plt.plot(train_model.history['val_accuracy'],marker="o",linestyle="-",color="darkcyan",markersize=10,lw=4)
plt.title('Model Accuracy\n',color="lavender",fontsize=20)
plt.ylabel('Accuracy',color="lavender",fontsize=15)
plt.xlabel('Epoch',color="lavender",fontsize=15)
plt.legend(['Train_Accuracy', 'Test_accuracy'], loc='upper left')
plt.show()

# %%
Model_6 = tf.keras.models.load_model('/content/drive/MyDrive/Colab Notebooks/Graduation Project/VGG19.h5')

CLASS_NAMES = list(TrainG.class_indices.keys())
predictions = np.argmax(Model_6.predict(testD), axis=1)

acc = accuracy_score(testD.labels, predictions)
cm = tf.math.confusion_matrix(testD.labels, predictions)
clr = classification_report(testD.labels, predictions, target_names=CLASS_NAMES)

print("Test Accuracy: {:.3f} %".format(acc * 100))

plt.figure(figsize=(8, 8))
sns.heatmap(cm, annot=True, fmt='g', vmin=0, cmap='Greens', cbar=False)
plt.xticks(ticks=np.arange(4)+0.5 , labels=CLASS_NAMES)
plt.yticks(ticks=np.arange(4)+0.5 , labels=CLASS_NAMES)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

print("Classification Report:\n-----------------------------\n", clr)
# Out:
# 2/2 [==============================] - 12s 4s/step
# Test Accuracy: 83.333 %
# Classification Report:
# -----------------------------
#                    precision    recall  f1-score   support
#
#      Normal Case       0.92      0.80      0.86        15
#  Pityriasis Alpa       0.70      0.93      0.80        15
# Tinea Versicolor       1.00      0.73      0.85        15
#         Vitiligo       0.81      0.87      0.84        15
#
#         accuracy                           0.83        60
#        macro avg       0.86      0.83      0.84        60
#     weighted avg       0.86      0.83      0.84        60

# %% [markdown]
# #MobileNet

# %%
MobileNet_Model=keras.applications.MobileNet(include_top=False,weights='imagenet',input_shape=(100,100,3),classes=4)
MobileNet_Model.trainable=False
pt=Input(shape=(100,100,3))
func=tensorflow.cast(pt,tensorflow.float32)
x=preprocess_input(func)
MobileNetModel=MobileNet_Model(x,training=False)
MobileNetModel=GlobalAveragePooling2D()(MobileNetModel)
MobileNetModel=Dropout(0.3)(MobileNetModel)
MobileNetModel=Dense(650,activation='relu',use_bias=True,kernel_regularizer =tf.keras.regularizers.l2( l=0.01))(MobileNetModel)
MobileNetModel=Dense(256,activation='relu',use_bias=True,kernel_regularizer =tf.keras.regularizers.l2( l=0.01))(MobileNetModel)
MobileNetModel=Dense(210,activation='relu',use_bias=True,kernel_regularizer =tf.keras.regularizers.l2( l=0.01))(MobileNetModel)
MobileNetModel=Dense(128,activation='relu',use_bias=True,kernel_regularizer =tf.keras.regularizers.l2( l=0.01))(MobileNetModel)
MobileNetModel=Dense(4,activation='softmax')(MobileNetModel)
Model_5=Model(inputs=pt,outputs=MobileNetModel)
Model_5.summary()
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Model: "model_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_18 (InputLayer)       [(None, 100, 100, 3)]     0
#
#  tf.cast_10 (TFOpLambda)     (None, 100, 100, 3)       0
#
#  tf.__operators__.getitem_10  (None, 100, 100, 3)      0
#   (SlicingOpLambda)
#
#  tf.nn.bias_add_10 (TFOpLamb  (None, 100, 100, 3)      0
#  da)
#
#  mobilenet_1.00_224 (Functio  (None, 3, 3, 1024)       3228864
#  nal)
#
#  global_average_pooling2d_7   (None, 1024)             0
#  (GlobalAveragePooling2D)
#
#  dropout_10 (Dropout)        (None, 1024)              0
#
#  dense_36 (Dense)            (None, 650)               666250
#
#  dense_37 (Dense)            (None, 256)               166656
#
#  dense_38 (Dense)            (None, 210)               53970
#
#  dense_39 (Dense)            (None, 128)               27008
#
#  dense_40 (Dense)            (None, 4)                 516
#
# =================================================================
# Total params: 4,143,264
# Trainable params: 914,400
# Non-trainable params: 3,228,864
# _________________________________________________________________

# %%
Model_5.compile(optimizer=keras.optimizers.RMSprop(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])
train_model = Model_5.fit(TrainG,validation_data=ValidG,epochs=80,batch_size=64)
# Out:
# Epoch 1/80
# 81/81 [==============================] - 68s 798ms/step - loss: 15.8174 - accuracy: 0.4047 - val_loss: 14.8215 - val_accuracy: 0.4797
# Epoch 2/80
# 81/81 [==============================] - 64s 787ms/step - loss: 14.0283 - accuracy: 0.5156 - val_loss: 13.2103 - val_accuracy: 0.5328
# Epoch 3/80
# 81/81 [==============================] - 53s 659ms/step - loss: 12.5310 - accuracy: 0.5502 - val_loss: 11.8761 - val_accuracy: 0.5547
# Epoch 4/80
# 81/81 [==============================] - 53s 650ms/step - loss: 11.2050 - accuracy: 0.5813 - val_loss: 10.5843 - val_accuracy: 0.5859
# Epoch 5/80
# 81/81 [==============================] - 53s 652ms/step - loss: 10.0816 - accuracy: 0.5999 - val_loss: 9.5084 - val_accuracy: 0.6500
# Epoch 6/80
# 81/81 [==============================] - 54s 660ms/step - loss: 9.1102 - accuracy: 0.6178 - val_loss: 8.7261 - val_accuracy: 0.6156
# Epoch 7/80
# 81/81 [==============================] - 53s 657ms/step - loss: 8.2945 - accuracy: 0.6314 - val_loss: 7.8991 - val_accuracy: 0.6344
# Epoch 8/80
# 81/81 [==============================] - 53s 656ms/step - loss: 7.6014 - accuracy: 0.6279 - val_loss: 7.3039 - val_accuracy: 0.6172
# Epoch 9/80
# 81/81 [==============================] - 64s 788ms/step - loss: 7.0090 - accuracy: 0.6310 - val_loss: 6.7855 - val_accuracy: 0.5953
# Epoch 10/80
# 81/81 [==============================] - 53s 653ms/step - loss: 6.5130 - accuracy: 0.6411 - val_loss: 6.2990 - val_accuracy: 0.6219
# Epoch 11/80
# 81/81 [==============================] - 62s 762ms/step - loss: 6.0680 - accuracy: 0.6299 - val_loss: 5.8582 - val_accuracy: 0.6219
# Epoch 12/80
# 81/81 [==============================] - 52s 635ms/step - loss: 5.6725 - accuracy: 0.6450 - val_loss: 5.4778 - val_accuracy: 0.6453
# Epoch 13/80
# 81/81 [==============================] - 53s 647ms/step - loss: 5.3225 - accuracy: 0.6415 - val_loss: 5.1581 - val_accuracy: 0.6875
# Epoch 14/80
# 81/81 [==============================] - 62s 764ms/step - loss: 5.0090 - accuracy: 0.6649 - val_loss: 4.8896 - val_accuracy: 0.6484
# Epoch 15/80
# 81/81 [==============================] - 53s 646ms/step - loss: 4.7354 - accuracy: 0.6621 - val_loss: 4.6092 - val_accuracy: 0.6562
# Epoch 16/80
# 81/81 [==============================] - 52s 642ms/step - loss: 4.4994 - accuracy: 0.6540 - val_loss: 4.3796 - val_accuracy: 0.6734
# Epoch 17/80
# 81/81 [==============================] - 52s 637ms/step - loss: 4.2686 - accuracy: 0.6680 - val_loss: 4.2214 - val_accuracy: 0.6438
# Epoch 18/80
# 81/81 [==============================] - 62s 771ms/step - loss: 4.0812 - accuracy: 0.6664 - val_loss: 4.0172 - val_accuracy: 0.6625
# Epoch 19/80
# 81/81 [==============================] - 63s 772ms/step - loss: 3.8995 - accuracy: 0.6699 - val_loss: 3.8384 - val_accuracy: 0.6328
# Epoch 20/80
# 81/81 [==============================] - 56s 683ms/step - loss: 3.7056 - accuracy: 0.6820 - val_loss: 3.6898 - val_accuracy: 0.6594
# Epoch 21/80
# 81/81 [==============================] - 62s 766ms/step - loss: 3.5560 - accuracy: 0.6742 - val_loss: 3.5381 - val_accuracy: 0.6391
# Epoch 22/80
# 81/81 [==============================] - 52s 628ms/step - loss: 3.4244 - accuracy: 0.6707 - val_loss: 3.3990 - val_accuracy: 0.6547
# Epoch 23/80
# 81/81 [==============================] - 62s 771ms/step - loss: 3.2862 - accuracy: 0.6715 - val_loss: 3.2433 - val_accuracy: 0.6578
# Epoch 24/80
# 81/81 [==============================] - 52s 643ms/step - loss: 3.1430 - accuracy: 0.6816 - val_loss: 3.1073 - val_accuracy: 0.6734
# Epoch 25/80
# 81/81 [==============================] - 51s 632ms/step - loss: 3.0351 - accuracy: 0.6862 - val_loss: 3.0325 - val_accuracy: 0.6562
# Epoch 26/80
# 81/81 [==============================] - 62s 767ms/step - loss: 2.9235 - accuracy: 0.6781 - val_loss: 2.9428 - val_accuracy: 0.6438
# Epoch 27/80
# 81/81 [==============================] - 62s 764ms/step - loss: 2.8240 - accuracy: 0.6874 - val_loss: 2.7663 - val_accuracy: 0.6719
# Epoch 28/80
# 81/81 [==============================] - 52s 640ms/step - loss: 2.6958 - accuracy: 0.6971 - val_loss: 2.6664 - val_accuracy: 0.6875
# Epoch 29/80
# 81/81 [==============================] - 52s 641ms/step - loss: 2.6451 - accuracy: 0.6897 - val_loss: 2.5968 - val_accuracy: 0.6906
# Epoch 30/80
# 81/81 [==============================] - 62s 769ms/step - loss: 2.5517 - accuracy: 0.6831 - val_loss: 2.5211 - val_accuracy: 0.6781
# Epoch 31/80
# 81/81 [==============================] - 62s 770ms/step - loss: 2.4750 - accuracy: 0.6847 - val_loss: 2.4534 - val_accuracy: 0.6750
# Epoch 32/80
# 81/81 [==============================] - 52s 638ms/step - loss: 2.3830 - accuracy: 0.6901 - val_loss: 2.4056 - val_accuracy: 0.6625
# Epoch 33/80
# 81/81 [==============================] - 62s 764ms/step - loss: 2.3353 - accuracy: 0.6862 - val_loss: 2.3518 - val_accuracy: 0.6703
# Epoch 34/80
# 81/81 [==============================] - 52s 633ms/step - loss: 2.2604 - accuracy: 0.7018 - val_loss: 2.2764 - val_accuracy: 0.6766
# Epoch 35/80
# 81/81 [==============================] - 62s 764ms/step - loss: 2.1947 - accuracy: 0.7022 - val_loss: 2.1977 - val_accuracy: 0.6859
# Epoch 36/80
# 81/81 [==============================] - 52s 636ms/step - loss: 2.1393 - accuracy: 0.6897 - val_loss: 2.1122 - val_accuracy: 0.7031
# Epoch 37/80
# 81/81 [==============================] - 62s 774ms/step - loss: 2.0752 - accuracy: 0.7018 - val_loss: 2.0685 - val_accuracy: 0.6844
# Epoch 38/80
# 81/81 [==============================] - 51s 627ms/step - loss: 2.0222 - accuracy: 0.6983 - val_loss: 2.0907 - val_accuracy: 0.6578
# Epoch 39/80
# 81/81 [==============================] - 63s 774ms/step - loss: 1.9627 - accuracy: 0.7033 - val_loss: 2.0357 - val_accuracy: 0.6766
# Epoch 40/80
# 81/81 [==============================] - 62s 768ms/step - loss: 1.9066 - accuracy: 0.7150 - val_loss: 1.9227 - val_accuracy: 0.6844
# Epoch 41/80
# 81/81 [==============================] - 52s 642ms/step - loss: 1.8755 - accuracy: 0.7185 - val_loss: 1.9115 - val_accuracy: 0.6875
# Epoch 42/80
# 81/81 [==============================] - 62s 764ms/step - loss: 1.8420 - accuracy: 0.7092 - val_loss: 1.8653 - val_accuracy: 0.6672
# Epoch 43/80
# 81/81 [==============================] - 62s 765ms/step - loss: 1.7980 - accuracy: 0.7170 - val_loss: 1.8246 - val_accuracy: 0.6984
# Epoch 44/80
# 81/81 [==============================] - 52s 637ms/step - loss: 1.7749 - accuracy: 0.7115 - val_loss: 1.7786 - val_accuracy: 0.6844
# Epoch 45/80
# 81/81 [==============================] - 62s 770ms/step - loss: 1.7169 - accuracy: 0.7220 - val_loss: 1.7460 - val_accuracy: 0.7063
# Epoch 46/80
# 81/81 [==============================] - 52s 635ms/step - loss: 1.6747 - accuracy: 0.7197 - val_loss: 1.7323 - val_accuracy: 0.6828
# Epoch 47/80
# 81/81 [==============================] - 62s 773ms/step - loss: 1.6665 - accuracy: 0.7243 - val_loss: 1.7459 - val_accuracy: 0.6703
# Epoch 48/80
# 81/81 [==============================] - 63s 777ms/step - loss: 1.6177 - accuracy: 0.7216 - val_loss: 1.6646 - val_accuracy: 0.6891
# Epoch 49/80
# 81/81 [==============================] - 62s 771ms/step - loss: 1.5939 - accuracy: 0.7364 - val_loss: 1.6089 - val_accuracy: 0.7250
# Epoch 50/80
# 81/81 [==============================] - 62s 773ms/step - loss: 1.5726 - accuracy: 0.7274 - val_loss: 1.6293 - val_accuracy: 0.6828
# Epoch 51/80
# 81/81 [==============================] - 51s 634ms/step - loss: 1.5323 - accuracy: 0.7263 - val_loss: 1.5927 - val_accuracy: 0.7031
# Epoch 52/80
# 81/81 [==============================] - 53s 650ms/step - loss: 1.5048 - accuracy: 0.7282 - val_loss: 1.5729 - val_accuracy: 0.6781
# Epoch 53/80
# 81/81 [==============================] - 52s 635ms/step - loss: 1.4800 - accuracy: 0.7422 - val_loss: 1.5471 - val_accuracy: 0.6875
# Epoch 54/80
# 81/81 [==============================] - 62s 763ms/step - loss: 1.4763 - accuracy: 0.7208 - val_loss: 1.4732 - val_accuracy: 0.7219
# Epoch 55/80
# 81/81 [==============================] - 51s 636ms/step - loss: 1.4501 - accuracy: 0.7290 - val_loss: 1.5163 - val_accuracy: 0.6766
# Epoch 56/80
# 81/81 [==============================] - 51s 624ms/step - loss: 1.4255 - accuracy: 0.7321 - val_loss: 1.4385 - val_accuracy: 0.7172
# Epoch 57/80
# 81/81 [==============================] - 62s 774ms/step - loss: 1.3825 - accuracy: 0.7379 - val_loss: 1.4106 - val_accuracy: 0.7344
# Epoch 58/80
# 81/81 [==============================] - 52s 635ms/step - loss: 1.3583 - accuracy: 0.7329 - val_loss: 1.4113 - val_accuracy: 0.7094
# Epoch 59/80
# 81/81 [==============================] - 62s 761ms/step - loss: 1.3731 - accuracy: 0.7368 - val_loss: 1.4222 - val_accuracy: 0.7188
# Epoch 60/80
# 81/81 [==============================] - 62s 763ms/step - loss: 1.3273 - accuracy: 0.7481 - val_loss: 1.3446 - val_accuracy: 0.7297
# Epoch 61/80
# 81/81 [==============================] - 52s 639ms/step - loss: 1.3202 - accuracy: 0.7379 - val_loss: 1.3744 - val_accuracy: 0.7000
# Epoch 62/80
# 81/81 [==============================] - 52s 638ms/step - loss: 1.2953 - accuracy: 0.7562 - val_loss: 1.3695 - val_accuracy: 0.7172
# Epoch 63/80
# 81/81 [==============================] - 62s 772ms/step - loss: 1.2548 - accuracy: 0.7586 - val_loss: 1.3176 - val_accuracy: 0.7281
# Epoch 64/80
# 81/81 [==============================] - 52s 637ms/step - loss: 1.2445 - accuracy: 0.7558 - val_loss: 1.3016 - val_accuracy: 0.7234
# Epoch 65/80
# 81/81 [==============================] - 71s 879ms/step - loss: 1.2264 - accuracy: 0.7574 - val_loss: 1.2941 - val_accuracy: 0.7266
# Epoch 66/80
# 81/81 [==============================] - 62s 767ms/step - loss: 1.2103 - accuracy: 0.7679 - val_loss: 1.2895 - val_accuracy: 0.7391
# Epoch 67/80
# 81/81 [==============================] - 51s 635ms/step - loss: 1.1891 - accuracy: 0.7710 - val_loss: 1.2377 - val_accuracy: 0.7453
# Epoch 68/80
# 81/81 [==============================] - 52s 644ms/step - loss: 1.1881 - accuracy: 0.7636 - val_loss: 1.2807 - val_accuracy: 0.7172
# Epoch 69/80
# 81/81 [==============================] - 53s 653ms/step - loss: 1.2070 - accuracy: 0.7426 - val_loss: 1.2618 - val_accuracy: 0.7203
# Epoch 70/80
# 81/81 [==============================] - 51s 628ms/step - loss: 1.1579 - accuracy: 0.7562 - val_loss: 1.2302 - val_accuracy: 0.7391
# Epoch 71/80
# 81/81 [==============================] - 62s 770ms/step - loss: 1.1514 - accuracy: 0.7656 - val_loss: 1.2132 - val_accuracy: 0.7359
# Epoch 72/80
# 81/81 [==============================] - 50s 622ms/step - loss: 1.1352 - accuracy: 0.7702 - val_loss: 1.2265 - val_accuracy: 0.7125
# Epoch 73/80
# 81/81 [==============================] - 63s 776ms/step - loss: 1.1373 - accuracy: 0.7586 - val_loss: 1.1896 - val_accuracy: 0.7563
# Epoch 74/80
# 81/81 [==============================] - 52s 642ms/step - loss: 1.1125 - accuracy: 0.7772 - val_loss: 1.1990 - val_accuracy: 0.7250
# Epoch 75/80
# 81/81 [==============================] - 63s 781ms/step - loss: 1.1036 - accuracy: 0.7749 - val_loss: 1.2239 - val_accuracy: 0.7000
# Epoch 76/80
# 81/81 [==============================] - 62s 770ms/step - loss: 1.0856 - accuracy: 0.7788 - val_loss: 1.1604 - val_accuracy: 0.7484
# Epoch 77/80
# 81/81 [==============================] - 53s 648ms/step - loss: 1.0530 - accuracy: 0.7865 - val_loss: 1.1800 - val_accuracy: 0.7547
# Epoch 78/80
# 81/81 [==============================] - 52s 639ms/step - loss: 1.0799 - accuracy: 0.7784 - val_loss: 1.1610 - val_accuracy: 0.7281
# Epoch 79/80
# 81/81 [==============================] - 63s 778ms/step - loss: 1.0590 - accuracy: 0.7780 - val_loss: 1.1234 - val_accuracy: 0.7625
# Epoch 80/80
# 81/81 [==============================] - 53s 659ms/step - loss: 1.0539 - accuracy: 0.7819 - val_loss: 1.1388 - val_accuracy: 0.7266

# %%
plt.figure(figsize=(10,10))
plt.style.use("dark_background")
plt.plot(train_model.history['loss'],marker="o",linestyle="-",color="wheat",markersize=10,lw=4)
plt.plot(train_model.history['val_loss'],marker="o",linestyle="-",color="turquoise",markersize=10,lw=4)
plt.title('Model Loss\n',color="lavender",fontsize=20)
plt.ylabel('Loss',color="lavender",fontsize=15)
plt.xlabel('Epoch',color="lavender",fontsize=15)
plt.legend(['Train_Loss', 'Test_Loss'], loc='upper left')
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.style.use("dark_background")
plt.plot(train_model.history['accuracy'],marker="o",linestyle="-",color="yellow",markersize=10,lw=4)
plt.plot(train_model.history['val_accuracy'],marker="o",linestyle="-",color="darkcyan",markersize=10,lw=4)
plt.title('Model Accuracy\n',color="lavender",fontsize=20)
plt.ylabel('Accuracy',color="lavender",fontsize=15)
plt.xlabel('Epoch',color="lavender",fontsize=15)
plt.legend(['Train_Accuracy', 'Test_accuracy'], loc='upper left')
plt.show()

# %%
CLASS_NAMES = list(TrainG.class_indices.keys())
predictions = np.argmax(Model_5.predict(testD), axis=1)

acc = accuracy_score(testD.labels, predictions)
cm = tf.math.confusion_matrix(testD.labels, predictions)
clr = classification_report(testD.labels, predictions, target_names=CLASS_NAMES)

print("Test Accuracy: {:.3f} %".format(acc * 100))

plt.figure(figsize=(8, 8))
sns.heatmap(cm, annot=True, fmt='g', vmin=0, cmap='Greens', cbar=False)
plt.xticks(ticks=np.arange(4)+0.5 , labels=CLASS_NAMES)
plt.yticks(ticks=np.arange(4)+0.5 , labels=CLASS_NAMES)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

print("Classification Report:\n-----------------------------\n", clr)
# Out:
# 2/2 [==============================] - 2s 224ms/step
# Test Accuracy: 63.333 %
# Classification Report:
# -----------------------------
#                    precision    recall  f1-score   support
#
#      Normal Case       0.64      0.60      0.62        15
#  Pityriasis Alpa       0.55      0.80      0.65        15
# Tinea Versicolor       0.62      0.67      0.65        15
#         Vitiligo       0.88      0.47      0.61        15
#
#         accuracy                           0.63        60
#        macro avg       0.67      0.63      0.63        60
#     weighted avg       0.67      0.63      0.63        60

# %% [markdown]
# #Convertion highest accuracy model to tflite

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.models import load_model
from tensorflow import keras
import tensorflow as tf
import numpy as np

model = tf.keras.models.load_model('/content/drive/MyDrive/Colab Notebooks/Graduation Project/RESNET50.h5')
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_quant_model = converter.convert()
open('/content/drive/MyDrive/Colab Notebooks/Graduation Project/LastResnet50.tflite', "wb").write(tflite_quant_model)

# %%
labels = {0:'Normal Skin',1:'Pityriasis Alba', 2:'Tinea versicolor', 3:'Vitiligo'}
img = keras.preprocessing.image.load_img('/content/drive/MyDrive/Colab Notebooks/Graduation Project/testing/Normal Case/6 (1).png', target_size=(100,100))
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)
img.show()

with open('/content/drive/MyDrive/Colab Notebooks/Best1Resnet50.tflite', 'rb') as fid:
    tflite_model = fid.read()

tflite_interpreter = tf.lite.Interpreter(model_content=tflite_model)
input_details = tflite_interpreter.get_input_details()
output_details = tflite_interpreter.get_output_details()

tflite_interpreter.resize_tensor_input(input_details[0]['index'], (1, 100, 100, 3))
tflite_interpreter.resize_tensor_input(output_details[0]['index'], (1, 4))
tflite_interpreter.allocate_tensors()

tflite_interpreter.set_tensor(input_details[0]['index'], img_array)
# Run inference
tflite_interpreter.invoke()
# Get prediction results
tflite_model_predictions = tflite_interpreter.get_tensor(output_details[0]['index'])

predicted_ids = np.argmax(tflite_model_predictions, axis=-1)
model = tf.keras.models.load_model('/content/drive/MyDrive/Colab Notebooks/Graduation Project/HighestModel4ClassVGG19.h5')

print(tflite_model_predictions)
print(labels[int(predicted_ids)])
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7F9C334136D0>
# [[0.9142274  0.01969322 0.0436351  0.02244428]]
# Normal Skin
